# %%
#Client ID= 171b2fccb73d64507b96
#Client Secret= 58e5b908893c969d63e9d87ecb8d72011032a611

# %%
import requests
import json

# %%
data={"client_id":"171b2fccb73d64507b96", "state":"Successful", "redirect_uri":"https://www.google.com"}
response=requests.get('https://github.com/login/oauth/authorize', params=data)
print(response.url)
# Out:
# https://github.com/login?client_id=171b2fccb73d64507b96&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D171b2fccb73d64507b96%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%26state%3DSuccessful

# %%
#code = a7fccc9776d28355580d

# %%
data={"client_id":"171b2fccb73d64507b96", "client_secret":"58e5b908893c969d63e9d87ecb8d72011032a611",
     "code":"a7fccc9776d28355580d", "redirect_uri":"https://www.google.com", "state":"Successful"}
r=requests.post('https://github.com/login/oauth/access_token', data=data, headers={"accept":"application/json"})
print(r.text)
# Out:
# {"access_token":"d1a987c8011516b37dfdcfe324d73c5f1bcbf91a","token_type":"bearer","scope":""}

# %%
r=requests.get('https://api.github.com/orgs/CodingNinjasCodes/repos',
               headers={"Authorization":"token d1a987c8011516b37dfdcfe324d73c5f1bcbf91a"})
data=r.json()
# Out:
# [{'id': 68499062,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2ODQ5OTA2Mg==',
#   'name': 'SmoothScrollJs',
#   'full_name': 'CodingNinjasCodes/SmoothScrollJs',
#   'private': False,
#   'owner': {'login': 'CodingNinjasCodes',
#    'id': 22269960,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjIyMjY5OTYw',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/22269960?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CodingNinjasCodes',
#    'html_url': 'https://github.com/CodingNinjasCodes',
#    'followers_url': 'https://api.github.com/users/CodingNinjasCodes/followers',
#    'following_url': 'https://api.github.com/users/CodingNinjasCodes/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/CodingNinjasCodes/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/CodingNinjasCodes/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/CodingNinjasCodes/subscriptions',
# ...

# %%
l=[]
for i in data:
    if not i['fork']:
        l.append([i['name'], i['watchers_count'], i['forks_count']])
l
# Out:
# [['SmoothScrollJs', 15, 4],
#  ['RubyTutorial', 15, 9],
#  ['Python3Tutorial', 5, 3],
#  ['HTMLandCssNotes', 11, 20],
#  ['Beacathon', 2, 8],
#  ['JSNotes', 5, 6],
#  ['learnml', 1, 0],
#  ['RubyNotebook', 2, 5]]

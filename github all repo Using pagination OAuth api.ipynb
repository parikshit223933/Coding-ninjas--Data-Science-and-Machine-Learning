# %%
#Client ID= 171b2fccb73d64507b96
#Client Secret= 58e5b908893c969d63e9d87ecb8d72011032a611

# %%
import json
import requests

# %%
data={"client_id":"171b2fccb73d64507b96", "redirect_uri":"https://www.google.com", "state":"Welcome", "scope":"repo"}
response=requests.get('https://github.com/login/oauth/authorize', params=data)
print(response.url)
# Out:
# https://github.com/login?client_id=171b2fccb73d64507b96&return_to=%2Flogin%2Foauth%2Fauthorize%3Fclient_id%3D171b2fccb73d64507b96%26redirect_uri%3Dhttps%253A%252F%252Fwww.google.com%26scope%3Drepo%26state%3DWelcome

# %%
#code= 46d19b1b52268ac6a00a

# %%
data={"client_id":"171b2fccb73d64507b96", "client_secret":"58e5b908893c969d63e9d87ecb8d72011032a611",
     "code":"46d19b1b52268ac6a00a", "redirect_uri":"https://www.google.com", "state":"Welcome"}
r=requests.post('https://github.com/login/oauth/access_token', data=data, headers={"accept":"application/json"})
print(r.text)
# Out:
# {"access_token":"5c12e03fc1103ac75a3e4e27f68f05e9da67081e","token_type":"bearer","scope":"repo"}

# %%
r=requests.get("https://api.github.com/orgs/fossasia/repos?page=1&per_page=100", params={"type":"all"},
               headers={"accept":"application/vnd.github.baptiste-preview+json", "Authorization":"token cd0653b525c887c01bf74c2d5477e3e85821503b"})
data=r.json()

data
# Out:
# [{'id': 4132843,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTMyODQz',
#   'name': 'x-mario',
#   'full_name': 'fossasia/x-mario',
#   'private': False,
#   'owner': {'login': 'fossasia',
#    'id': 6295529,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYyOTU1Mjk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6295529?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fossasia',
#    'html_url': 'https://github.com/fossasia',
#    'followers_url': 'https://api.github.com/users/fossasia/followers',
#    'following_url': 'https://api.github.com/users/fossasia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fossasia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fossasia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fossasia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fossasia/orgs',
#    'repos_url': 'https://api.github.com/users/fossasia/repos',
# ...

# %%
l=[]
count=0
for i in data:
    l.append(i['name'])
    count+=1
print(count)
# Out:
# 100

# %%
r=requests.get("https://api.github.com/orgs/fossasia/repos?page=2&per_page=100", params={"type":"all"},
               headers={"accept":"application/vnd.github.baptiste-preview+json", "Authorization":"token cd0653b525c887c01bf74c2d5477e3e85821503b"})
data2=r.json()

data2
# Out:
# [{'id': 64299564,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2NDI5OTU2NA==',
#   'name': 'loklak_wp_plugins',
#   'full_name': 'fossasia/loklak_wp_plugins',
#   'private': False,
#   'owner': {'login': 'fossasia',
#    'id': 6295529,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYyOTU1Mjk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6295529?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fossasia',
#    'html_url': 'https://github.com/fossasia',
#    'followers_url': 'https://api.github.com/users/fossasia/followers',
#    'following_url': 'https://api.github.com/users/fossasia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fossasia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fossasia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fossasia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fossasia/orgs',
# ...

# %%
l2=[]
count=0
for i in data2:
    l2.append(i['name'])
    count+=1
print(count)
# Out:
# 100

# %%
r=requests.get("https://api.github.com/orgs/fossasia/repos?page=3&per_page=100", params={"type":"all"},
               headers={"accept":"application/vnd.github.baptiste-preview+json", "Authorization":"token cd0653b525c887c01bf74c2d5477e3e85821503b"})
data3=r.json()

data3
# Out:
# [{'id': 111976620,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxMTE5NzY2MjA=',
#   'name': 'pslab-experiments',
#   'full_name': 'fossasia/pslab-experiments',
#   'private': False,
#   'owner': {'login': 'fossasia',
#    'id': 6295529,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjYyOTU1Mjk=',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/6295529?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fossasia',
#    'html_url': 'https://github.com/fossasia',
#    'followers_url': 'https://api.github.com/users/fossasia/followers',
#    'following_url': 'https://api.github.com/users/fossasia/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/fossasia/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/fossasia/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/fossasia/subscriptions',
#    'organizations_url': 'https://api.github.com/users/fossasia/orgs',
# ...

# %%
l3=[]
count=0
for i in data3:
    l3.append(i['name'])
    count+=1
print(count)
# Out:
# 27

# %%
final_list=[l, l2, l3]
# Out:
# [['x-mario',
#   'phimpme-android',
#   'phimpme-drupal',
#   'xmario_buildscript',
#   'pslab-case',
#   'meilix-systemlock',
#   'fossasia10-drupal',
#   'fossasia11-drupal',
#   'blog.fossasia.org',
#   '2010.fossasia.org',
#   '2014.fossasia.org',
#   'meilix',
#   'phimpme-wordpress',
#   '2015.fossasia.org',
#   'badge-magic-android',
#   'api.fossasia.net',
#   'directory.api.fossasia.net',
#   'common.api.fossasia.net',
#   'cmap.api.fossasia.net',
#   'feed.api.freifunk.net',
#   'feed.api.fossasia.net',
#   'fossasia-communities',
#   'sg18.sciencehack.asia',
#   'gci14.fossasia.org',
#   'fossasia-nodemailer',
#   '2011.fossasia.org',
#   '2012.fossasia.org',
#   'labs.fossasia.org',
#   'fossasia.net',
#   'foss.vn',
#   'libregraphics.asia',
#   'perspektive89.com',
#   'susi_smart_box',
#   'hotelxoai.com',
#   'yaydoc-artwork',
#   'fossasia-companion-android',
#   'loklak_webclient',
#   'circle-knitting',
#   'open-event-attendee-android',
#   '2018.fossasia.org',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8], [1, 0.6], [9, 11]])

# %%
plt.scatter(x[:, 0], x[:, 1])
plt.show()

# %%
def fit(data, k, max_iter):

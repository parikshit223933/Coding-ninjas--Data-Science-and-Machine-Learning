# %%
from nltk.corpus import movie_reviews
documents=[]
for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category):
        documents.append((movie_reviews.words(fileid), category))

# %%
import random
random.shuffle(documents)

# %%
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.corpus import stopwords
import string
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
stops=set(stopwords.words('english'))
punctuations=list(string.punctuation)
stops.update(punctuations)
def get_simple_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    if tag.startswith('N'):
        return wordnet.NOUN
    if tag.startswith('V'):
        return wordnet.VERB
    if tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
def clean_review(words):
    clean_words=[]
    for word in words:
        if word.lower() not in stops:
            pos=pos_tag([word])[0][1]
            clean_word=lemmatizer.lemmatize(word, pos=get_simple_pos(pos))
            clean_words.append(clean_word.lower())
    return clean_words

# %%
docs=[(clean_review(document), category) for document, category in documents]

# %%
all_words=[]
for tup in docs:
    all_words+=tup[0]

# %%
import nltk
freq=nltk.FreqDist(all_words)
common=freq.most_common(3000)
features=[i[0] for i in common]
features
# Out:
# ['film',
#  'movie',
#  'one',
#  'make',
#  'like',
#  'character',
#  'get',
#  'see',
#  'go',
#  'time',
#  'well',
#  'scene',
#  'even',
#  'good',
#  'story',
#  'take',
#  'would',
#  'much',
#  'come',
#  'also',
#  'bad',
#  'give',
#  'life',
#  'two',
#  'look',
#  'way',
#  'know',
#  'seem',
#  'first',
#  'end',
#  '--',
#  'year',
#  'work',
#  'thing',
#  'plot',
#  'say',
#  'play',
#  'really',
#  'little',
#  'show',
#  'people',
#  'could',
#  'man',
#  'star',
#  'love',
#  'never',
#  'try',
#  'great',
#  'director',
#  'best',
#  'performance',
#  'new',
#  'big',
#  'many',
#  'action',
#  'actor',
#  'want',
#  'u',
#  'watch',
#  'find',
#  'think',
#  'role',
#  'act',
#  'another',
#  'back',
#  'audience',
#  'something',
#  'world',
#  'turn',
#  'still',
#  'day',
#  'old',
#  'set',
#  'however',
#  'use',
#  'every',
#  'begin',
#  'though',
#  'guy',
#  'part',
#  'comedy',
#  'feel',
#  'cast',
#  'real',
#  'enough',
#  'around',
#  'point',
#  'interest',
#  'last',
#  'run',
#  'write',
#  'young',
#  'may',
#  'fact',
#  'name',
#  'long',
#  'funny',
#  'script',
#  'actually',
#  'right',
#  'woman',
#  'minute',
#  'effect',
#  'almost',
#  'lot',
#  'friend',
#  'nothing',
#  'john',
#  'place',
#  'although',
#  'screen',
#  'played',
#  'ever',
#  'start',
#  'moment',
#  'since',
#  'line',
#  'call',
#  'become',
#  'tell',
#  'lead',
#  'kill',
#  'original',
#  'help',
#  'high',
#  'family',
#  'without',
#  'three',
#  'problem',
#  'girl',
#  'picture',
#  'least',
#  'quite',
#  'sequence',
#  'need',
#  'away',
#  'course',
#  'laugh',
#  'might',
#  'far',
#  'fall',
#  'rather',
#  'must',
#  'anything',
#  'include',
#  'put',
#  'bit',
#  'child',
#  'job',
#  'yet',
#  'american',
#  'follow',
#  'keep',
#  'wife',
#  'alien',
#  'kind',
#  'hour',
#  'hard',
#  'always',
#  'reason',
#  'fun',
#  'head',
#  'feature',
#  'attempt',
#  'special',
#  'home',
#  'hand',
#  'hollywood',
#  'human',
#  'instead',
#  'lose',
#  'sense',
#  'move',
#  'war',
#  'mind',
#  'series',
#  'face',
#  'night',
#  'black',
#  'half',
#  'let',
#  'probably',
#  'shot',
#  'kid',
#  'along',
#  'men',
#  'everything',
#  'idea',
#  'pretty',
#  'direct',
#  'becomes',
#  'dialogue',
#  'sure',
#  'together',
#  'force',
#  'money',
#  'involve',
#  'believe',
#  'talk',
#  'father',
#  'whole',
#  'save',
#  'fight',
#  'horror',
#  'death',
#  'appear',
#  'boy',
#  'everyone',
#  'city',
#  'question',
#  'sex',
#  'music',
#  'do',
#  'less',
#  'release',
#  'second',
#  'couple',
#  'thought',
#  'brother',
#  'eye',
#  'perhaps',
#  'small',
#  'case',
#  'next',
#  'especially',
#  'happen',
#  'expect',
#  'meet',
#  'relationship',
#  '10',
#  'word',
#  'mother',
#  'base',
#  'create',
#  'care',
#  'completely',
#  'rest',
#  '2',
#  'whose',
#  'writer',
#  'evil',
#  'change',
#  'different',
#  'james',
#  'sound',
#  'simply',
#  'mean',
#  'book',
#  'mr',
#  'anyone',
#  'school',
#  'joke',
#  'michael',
#  'late',
#  'review',
#  'top',
#  'several',
#  'dead',
#  'humor',
#  'live',
#  'suppose',
#  'lack',
#  'left',
#  'add',
#  'true',
#  'matter',
#  'town',
#  'entire',
#  'hit',
#  'group',
#  'found',
#  'comic',
#  'fan',
#  'soon',
#  'house',
#  'someone',
#  'main',
#  'entertain',
#  'game',
#  'tv',
#  'side',
#  'leave',
#  'wrong',
#  'present',
#  'wonder',
#  'david',
#  'else',
#  'element',
#  'either',
#  'full',
#  'final',
#  'later',
#  'unfortunately',
#  'stop',
#  'car',
#  'viewer',
#  'murder',
#  'open',
#  'style',
#  'enjoy',
#  'camera',
#  'return',
#  'support',
#  'robert',
#  'credit',
#  'often',
#  'provide',
#  'power',
#  'die',
#  'deal',
#  'son',
#  'hero',
#  'behind',
#  'certainly',
#  'person',
#  'title',
#  'result',
#  'team',
#  'scream',
#  'despite',
#  'perfect',
#  'finally',
#  'order',
#  'video',
#  'nice',
#  'killer',
#  'stand',
#  'note',
#  'maybe',
#  'piece',
#  'miss',
#  'summer',
#  'fine',
#  'past',
#  'able',
#  'view',
#  'consider',
#  'classic',
#  'example',
#  'strong',
#  'voice',
#  'daughter',
#  'hope',
#  'theater',
#  'situation',
#  'production',
#  'sort',
#  'thriller',
#  'event',
#  'close',
#  'white',
#  'dog',
#  'drama',
#  'talent',
#  'break',
#  'kevin',
#  'joe',
#  'body',
#  'worth',
#  'earth',
#  'heart',
#  'short',
#  'bring',
#  'cut',
#  'version',
#  'level',
#  'self',
#  'dark',
#  'room',
#  'dream',
#  'cop',
#  'early',
#  'opening',
#  'nearly',
#  'upon',
#  'experience',
#  'screenplay',
#  'ask',
#  'light',
#  'major',
#  'age',
#  'art',
#  'violence',
#  'throughout',
#  'figure',
#  'ship',
#  'direction',
#  'beautiful',
#  'jack',
#  'computer',
#  'exactly',
#  'realize',
#  'obvious',
#  'state',
#  'genre',
#  'disney',
#  'plan',
#  'already',
#  'others',
#  'number',
#  'fill',
#  'wait',
#  'guess',
#  'space',
#  'waste',
#  'five',
#  'deep',
#  'offer',
#  'simple',
#  'jackie',
#  'four',
#  'form',
#  'king',
#  'learn',
#  'twist',
#  'surprise',
#  'touch',
#  'walk',
#  'pull',
#  'career',
#  'chase',
#  'flick',
#  'sometimes',
#  'rise',
#  'oscar',
#  'novel',
#  'hold',
#  'member',
#  'truly',
#  'battle',
#  'filmmaker',
#  '1',
#  'boring',
#  'tom',
#  'husband',
#  'easy',
#  'pace',
#  'drug',
#  'god',
#  'lee',
#  'peter',
#  'type',
#  'sequel',
#  'york',
#  'planet',
#  'charm',
#  'fiction',
#  'carry',
#  'win',
#  'happens',
#  'parent',
#  'yes',
#  'saw',
#  'song',
#  'tale',
#  'score',
#  'remember',
#  'quickly',
#  'stupid',
#  'romantic',
#  'possible',
#  'gun',
#  'chance',
#  'villain',
#  'material',
#  'extremely',
#  'manages',
#  'future',
#  'attention',
#  'mostly',
#  'de',
#  'project',
#  'particularly',
#  'single',
#  'escape',
#  'focus',
#  'quality',
#  'paul',
#  'police',
#  'mention',
#  'none',
#  'co',
#  'crime',
#  'stay',
#  'eventually',
#  'decide',
#  'wild',
#  'hell',
#  'van',
#  'emotional',
#  'image',
#  'science',
#  'sit',
#  'dr',
#  'smith',
#  'large',
#  'shoot',
#  'pay',
#  'girlfriend',
#  'living',
#  'steal',
#  'detail',
#  'rock',
#  'drive',
#  'george',
#  'actress',
#  'success',
#  'low',
#  'theme',
#  'alone',
#  'cover',
#  'obviously',
#  'television',
#  'usually',
#  'within',
#  'million',
#  'among',
#  'water',
#  'cause',
#  'premise',
#  'middle',
#  'read',
#  'aspect',
#  '3',
#  'complete',
#  'secret',
#  'flaw',
#  'subject',
#  'across',
#  'understand',
#  'except',
#  'chris',
#  'poor',
#  'mission',
#  'slow',
#  'history',
#  'reality',
#  'whether',
#  'local',
#  'wonderful',
#  'oh',
#  'serious',
#  'amaze',
#  'law',
#  'agent',
#  'crew',
#  'important',
#  'motion',
#  'effort',
#  'happy',
#  'mark',
#  'explain',
#  'impressive',
#  'studio',
#  'america',
#  'near',
#  'office',
#  'told',
#  'stuff',
#  'robin',
#  'basically',
#  'entertainment',
#  'street',
#  'recent',
#  'cool',
#  'produce',
#  'easily',
#  'apparently',
#  'ryan',
#  'screenwriter',
#  'wish',
#  'mystery',
#  'williams',
#  'message',
#  'attack',
#  'party',
#  'vampire',
#  'somehow',
#  'lie',
#  'blood',
#  'fear',
#  'william',
#  'bill',
#  'fast',
#  'batman',
#  'control',
#  'fire',
#  'doubt',
#  'jones',
#  'suspense',
#  'brings',
#  'straight',
#  'producer',
#  'difficult',
#  'red',
#  'hilarious',
#  'certain',
#  'ben',
#  'romance',
#  'appeal',
#  'ago',
#  'country',
#  'approach',
#  'effective',
#  'business',
#  'company',
#  'presence',
#  'popular',
#  'due',
#  'confuse',
#  'answer',
#  'throw',
#  'fly',
#  'annoy',
#  'critic',
#  'adult',
#  'fail',
#  'trouble',
#  'smart',
#  'teen',
#  'dramatic',
#  'third',
#  'general',
#  'class',
#  'budget',
#  'rich',
#  'date',
#  'discover',
#  'speak',
#  'clear',
#  'sexual',
#  'anyway',
#  'us',
#  'surprisingly',
#  'personal',
#  '4',
#  'cross',
#  'emotion',
#  'share',
#  'decides',
#  'somewhat',
#  'choice',
#  'rat',
#  'harry',
#  'ability',
#  'prison',
#  'sister',
#  'cinema',
#  'excite',
#  'successful',
#  'former',
#  'similar',
#  'previous',
#  'jim',
#  'absolutely',
#  'student',
#  'strange',
#  'allow',
#  'intelligent',
#  'excellent',
#  'familiar',
#  'leaf',
#  'rule',
#  'dance',
#  'towards',
#  'predictable',
#  'giant',
#  'bob',
#  'powerful',
#  'beyond',
#  'visual',
#  'box',
#  'shock',
#  'b',
#  'animate',
#  'trailer',
#  'la',
#  'nature',
#  'r',
#  'victim',
#  'sam',
#  'tone',
#  'deliver',
#  'usual',
#  'definitely',
#  'catch',
#  'martin',
#  'clever',
#  'blue',
#  'master',
#  'brilliant',
#  'felt',
#  'murphy',
#  'manage',
#  'wedding',
#  'suspect',
#  'stone',
#  'scary',
#  'reveal',
#  'capture',
#  'appearance',
#  'bunch',
#  'solid',
#  'musical',
#  'favorite',
#  'pick',
#  'rating',
#  'land',
#  'mess',
#  'reach',
#  'handle',
#  'travel',
#  'free',
#  'seriously',
#  'treat',
#  'grow',
#  'potential',
#  'track',
#  'wear',
#  'huge',
#  'hunt',
#  'search',
#  'continue',
#  'week',
#  'amount',
#  'sweet',
#  'l',
#  'married',
#  'unlike',
#  'non',
#  'join',
#  'perfectly',
#  'issue',
#  'hate',
#  'park',
#  'ex',
#  'scott',
#  'enjoyable',
#  'likely',
#  'strike',
#  'e',
#  'decent',
#  'bond',
#  'adventure',
#  'immediately',
#  'frank',
#  'heard',
#  'ten',
#  'cameron',
#  'private',
#  'depth',
#  'truman',
#  'door',
#  'bruce',
#  'monster',
#  'impossible',
#  'richard',
#  'overall',
#  'fails',
#  'carter',
#  'cold',
#  'inside',
#  'race',
#  'particular',
#  'purpose',
#  'toy',
#  'step',
#  'truth',
#  'merely',
#  'trek',
#  'sight',
#  'color',
#  'prove',
#  'sign',
#  'neither',
#  'struggle',
#  'gag',
#  'air',
#  'mar',
#  'design',
#  'ultimately',
#  'drop',
#  'pop',
#  'spirit',
#  'modern',
#  'club',
#  'list',
#  'personality',
#  'brought',
#  'thrill',
#  'tim',
#  'otherwise',
#  '5',
#  'cliche',
#  'society',
#  'term',
#  'allen',
#  'wood',
#  'dumb',
#  'key',
#  'fashion',
#  'player',
#  'government',
#  'serve',
#  'succeed',
#  'talented',
#  'various',
#  'opportunity',
#  'amuse',
#  'political',
#  'west',
#  'mouth',
#  'soundtrack',
#  'sell',
#  'development',
#  'angel',
#  'army',
#  'raise',
#  'female',
#  'silly',
#  'haunt',
#  'english',
#  'train',
#  'detective',
#  'steve',
#  'slightly',
#  'month',
#  'introduce',
#  'hank',
#  'require',
#  'kiss',
#  'tension',
#  'spend',
#  'imagine',
#  'roll',
#  'lover',
#  'eddie',
#  'compare',
#  'foot',
#  'grace',
#  'earlier',
#  'disaster',
#  'creature',
#  'chan',
#  'today',
#  'baby',
#  'heavy',
#  '90',
#  'six',
#  'hill',
#  'cannot',
#  'max',
#  'memorable',
#  'award',
#  'background',
#  'totally',
#  'episode',
#  'rescue',
#  'ground',
#  'leader',
#  'respect',
#  'front',
#  'woody',
#  'fi',
#  'notice',
#  'soldier',
#  'ape',
#  'hop',
#  'arm',
#  'engage',
#  'machine',
#  'edit',
#  'sci',
#  'animation',
#  'ride',
#  'terrible',
#  'doctor',
#  'costume',
#  'mary',
#  'simon',
#  'steven',
#  'actual',
#  'constantly',
#  'impact',
#  'british',
#  'entirely',
#  'queen',
#  'minor',
#  'fantasy',
#  'standard',
#  'promise',
#  'convincing',
#  'suffer',
#  'quick',
#  'cinematography',
#  'atmosphere',
#  'nick',
#  'island',
#  '8',
#  'typical',
#  'rush',
#  'officer',
#  'menace',
#  'brief',
#  'animal',
#  'spent',
#  'ridiculous',
#  'double',
#  'grant',
#  'road',
#  'bug',
#  'violent',
#  'trip',
#  'partner',
#  'subtle',
#  'building',
#  'adam',
#  'cameo',
#  'fairly',
#  'dollar',
#  'inspire',
#  'seven',
#  'cheap',
#  'suddenly',
#  'willis',
#  'dress',
#  'beauty',
#  'concept',
#  'highly',
#  'store',
#  'remain',
#  'whatever',
#  'bore',
#  'college',
#  'complex',
#  'president',
#  'flat',
#  'recommend',
#  'mike',
#  'dull',
#  'basic',
#  'ii',
#  'pair',
#  'suit',
#  'indeed',
#  'brain',
#  'kick',
#  'plenty',
#  'cute',
#  'outside',
#  'titanic',
#  'recently',
#  'frame',
#  'godzilla',
#  'meanwhile',
#  'cinematic',
#  'climax',
#  'intrigue',
#  'hear',
#  'awful',
#  'clearly',
#  'x',
#  'tough',
#  'longer',
#  'prof',
#  'buddy',
#  'forget',
#  'protagonist',
#  'century',
#  'conclusion',
#  'admit',
#  'period',
#  'common',
#  'realistic',
#  'believable',
#  'lawyer',
#  'chemistry',
#  'sean',
#  'scientist',
#  'possibly',
#  'encounter',
#  'language',
#  'band',
#  'brown',
#  'french',
#  'hang',
#  'twenty',
#  'aside',
#  'male',
#  'carrey',
#  'camp',
#  'sing',
#  'delivers',
#  'thin',
#  'jerry',
#  'slowly',
#  'jackson',
#  'hot',
#  'system',
#  'center',
#  ...]

# %%
training_documents=docs[0:1500]
testing_documents=docs[1500:]

# %%
def get_feature_dict(words):
    current_features={}
    words_set=set(words)
    for w in features:
        current_features[w]=w in words_set
    return current_features

# %%
training_data=[(get_feature_dict(doc), category)for doc, category in training_documents]

# %%
testing_data=[(get_feature_dict(doc), category)for doc, category in testing_documents]

# %%
from nltk import NaiveBayesClassifier
clf=NaiveBayesClassifier.train(training_data)

# %%
nltk.classify.accuracy(clf, testing_data)
# Out:
# 0.812

# %%
clf.show_most_informative_features(500)
# Out:
# Most Informative Features
#              outstanding = True              pos : neg    =     18.8 : 1.0
#                ludicrous = True              neg : pos    =     11.5 : 1.0
#                   poorly = True              neg : pos    =      9.2 : 1.0
#             breathtaking = True              pos : neg    =      9.2 : 1.0
#                stupidity = True              neg : pos    =      9.1 : 1.0
#                   spacey = True              pos : neg    =      8.9 : 1.0
#              wonderfully = True              pos : neg    =      8.0 : 1.0
#                    inept = True              neg : pos    =      7.3 : 1.0
#                   turkey = True              neg : pos    =      7.1 : 1.0
#                   alicia = True              neg : pos    =      7.1 : 1.0
#                   seagal = True              neg : pos    =      7.1 : 1.0
#                     anna = True              pos : neg    =      6.5 : 1.0
#                    bland = True              neg : pos    =      6.5 : 1.0
#                    jolie = True              neg : pos    =      6.4 : 1.0
#                      era = True              pos : neg    =      6.0 : 1.0
#               ridiculous = True              neg : pos    =      5.9 : 1.0
#                  freedom = True              pos : neg    =      5.8 : 1.0
#                   mature = True              pos : neg    =      5.7 : 1.0
#                    awful = True              neg : pos    =      5.7 : 1.0
#                  idiotic = True              neg : pos    =      5.5 : 1.0
#              beautifully = True              pos : neg    =      5.3 : 1.0
#                   random = True              neg : pos    =      5.3 : 1.0
#               schumacher = True              neg : pos    =      5.0 : 1.0
#                  refresh = True              pos : neg    =      5.0 : 1.0
#                 lebowski = True              pos : neg    =      5.0 : 1.0
#                     lame = True              neg : pos    =      4.9 : 1.0
#                    waste = True              neg : pos    =      4.8 : 1.0
#                    plant = True              neg : pos    =      4.8 : 1.0
#                     grip = True              pos : neg    =      4.7 : 1.0
#               henstridge = True              neg : pos    =      4.6 : 1.0
#                      obi = True              pos : neg    =      4.6 : 1.0
#                    damon = True              pos : neg    =      4.5 : 1.0
#                   german = True              pos : neg    =      4.5 : 1.0
#                 ordinary = True              pos : neg    =      4.5 : 1.0
#                    anger = True              pos : neg    =      4.4 : 1.0
#                  fiennes = True              pos : neg    =      4.4 : 1.0
#                   castle = True              pos : neg    =      4.4 : 1.0
#                  balance = True              pos : neg    =      4.4 : 1.0
#                 terrific = True              pos : neg    =      4.3 : 1.0
#                      eve = True              neg : pos    =      4.3 : 1.0
#                  garbage = True              neg : pos    =      4.3 : 1.0
#                  pattern = True              pos : neg    =      4.3 : 1.0
#            uninteresting = True              neg : pos    =      4.3 : 1.0
#                    ideal = True              pos : neg    =      4.3 : 1.0
#                   sinise = True              neg : pos    =      4.2 : 1.0
#                painfully = True              neg : pos    =      4.2 : 1.0
#                  crystal = True              neg : pos    =      4.2 : 1.0
#               whatsoever = True              neg : pos    =      4.1 : 1.0
#                    inane = True              neg : pos    =      4.1 : 1.0
#                    poker = True              pos : neg    =      4.1 : 1.0
#                     jedi = True              pos : neg    =      4.1 : 1.0
#                      sat = True              neg : pos    =      4.1 : 1.0
#                   sidney = True              pos : neg    =      4.1 : 1.0
#                     dull = True              neg : pos    =      4.1 : 1.0
#               delightful = True              pos : neg    =      4.0 : 1.0
#               friendship = True              pos : neg    =      4.0 : 1.0
#                 contrast = True              pos : neg    =      4.0 : 1.0
#                   superb = True              pos : neg    =      4.0 : 1.0
#                  unfunny = True              neg : pos    =      4.0 : 1.0
#                   boring = True              neg : pos    =      4.0 : 1.0
#               uninspired = True              neg : pos    =      3.9 : 1.0
#                   stupid = True              neg : pos    =      3.9 : 1.0
#            extraordinary = True              pos : neg    =      3.9 : 1.0
#             respectively = True              pos : neg    =      3.9 : 1.0
#                     zeta = True              neg : pos    =      3.9 : 1.0
#                 flawless = True              pos : neg    =      3.9 : 1.0
#                  chuckle = True              neg : pos    =      3.8 : 1.0
#                  tedious = True              neg : pos    =      3.8 : 1.0
#                      jar = True              pos : neg    =      3.8 : 1.0
#                pointless = True              neg : pos    =      3.7 : 1.0
#            appropriately = True              pos : neg    =      3.7 : 1.0
#                   insult = True              neg : pos    =      3.6 : 1.0
#                 lifeless = True              neg : pos    =      3.6 : 1.0
#                 detailed = True              pos : neg    =      3.6 : 1.0
#                   affect = True              pos : neg    =      3.6 : 1.0
#                   graham = True              pos : neg    =      3.6 : 1.0
#                    badly = True              neg : pos    =      3.6 : 1.0
#                 religion = True              pos : neg    =      3.6 : 1.0
#                   redeem = True              neg : pos    =      3.6 : 1.0
#                     pitt = True              pos : neg    =      3.5 : 1.0
#                  stiller = True              pos : neg    =      3.5 : 1.0
#                   subtle = True              pos : neg    =      3.5 : 1.0
#                innocence = True              pos : neg    =      3.5 : 1.0
#                fantastic = True              pos : neg    =      3.5 : 1.0
#                memorable = True              pos : neg    =      3.4 : 1.0
#                   welles = True              neg : pos    =      3.4 : 1.0
#                   allows = True              pos : neg    =      3.4 : 1.0
#                   regard = True              pos : neg    =      3.4 : 1.0
#                     wire = True              neg : pos    =      3.4 : 1.0
#                laughable = True              neg : pos    =      3.4 : 1.0
#                 portrait = True              pos : neg    =      3.4 : 1.0
#                  triumph = True              pos : neg    =      3.4 : 1.0
#                realistic = True              pos : neg    =      3.4 : 1.0
#                embarrass = True              neg : pos    =      3.3 : 1.0
#                  frankly = True              neg : pos    =      3.3 : 1.0
#                    patch = True              neg : pos    =      3.3 : 1.0
#                  freddie = True              neg : pos    =      3.3 : 1.0
#                 politics = True              pos : neg    =      3.3 : 1.0
#              consequence = True              pos : neg    =      3.3 : 1.0
#                 parallel = True              pos : neg    =      3.2 : 1.0
#              brilliantly = True              pos : neg    =      3.2 : 1.0
#                   belief = True              pos : neg    =      3.2 : 1.0
#                  command = True              pos : neg    =      3.2 : 1.0
#                portrayal = True              pos : neg    =      3.2 : 1.0
#                  portray = True              pos : neg    =      3.2 : 1.0
#                   harris = True              pos : neg    =      3.2 : 1.0
#                   amanda = True              neg : pos    =      3.2 : 1.0
#                  october = True              pos : neg    =      3.2 : 1.0
#                  francis = True              pos : neg    =      3.2 : 1.0
#                   tucker = True              pos : neg    =      3.2 : 1.0
#                formulaic = True              neg : pos    =      3.2 : 1.0
#                    idiot = True              neg : pos    =      3.2 : 1.0
#                  delight = True              pos : neg    =      3.2 : 1.0
#                   lethal = True              neg : pos    =      3.2 : 1.0
#                 nonsense = True              neg : pos    =      3.2 : 1.0
#                    blair = True              neg : pos    =      3.2 : 1.0
#                perfectly = True              pos : neg    =      3.1 : 1.0
#                excellent = True              pos : neg    =      3.1 : 1.0
#                  comfort = True              pos : neg    =      3.1 : 1.0
#                portrayed = True              pos : neg    =      3.1 : 1.0
#                   depict = True              pos : neg    =      3.1 : 1.0
#                 terrible = True              neg : pos    =      3.1 : 1.0
#                effective = True              pos : neg    =      3.1 : 1.0
#                  flubber = True              neg : pos    =      3.0 : 1.0
#                   prinze = True              neg : pos    =      3.0 : 1.0
#                  sandler = True              neg : pos    =      3.0 : 1.0
#                       54 = True              neg : pos    =      3.0 : 1.0
#                 banderas = True              neg : pos    =      3.0 : 1.0
#                malkovich = True              pos : neg    =      3.0 : 1.0
#                   dillon = True              pos : neg    =      3.0 : 1.0
#                   anakin = True              pos : neg    =      3.0 : 1.0
#                     antz = True              pos : neg    =      3.0 : 1.0
#                    upper = True              pos : neg    =      3.0 : 1.0
#                     deny = True              pos : neg    =      3.0 : 1.0
#                    uncle = True              pos : neg    =      3.0 : 1.0
#                    shine = True              pos : neg    =      3.0 : 1.0
#              emotionally = True              pos : neg    =      3.0 : 1.0
#                  natural = True              pos : neg    =      2.9 : 1.0
#                 anywhere = True              neg : pos    =      2.9 : 1.0
#                     epic = True              pos : neg    =      2.9 : 1.0
#               nomination = True              pos : neg    =      2.9 : 1.0
#                   mildly = True              neg : pos    =      2.9 : 1.0
#                    notch = True              pos : neg    =      2.9 : 1.0
#                    hokey = True              neg : pos    =      2.9 : 1.0
#                      ala = True              neg : pos    =      2.9 : 1.0
#                 scorsese = True              pos : neg    =      2.8 : 1.0
#                   truman = True              pos : neg    =      2.8 : 1.0
#                  nervous = True              pos : neg    =      2.8 : 1.0
#                    julie = True              neg : pos    =      2.8 : 1.0
#                 terribly = True              neg : pos    =      2.8 : 1.0
#                    equal = True              pos : neg    =      2.8 : 1.0
#               sutherland = True              neg : pos    =      2.8 : 1.0
#                     cave = True              neg : pos    =      2.8 : 1.0
#                  painful = True              neg : pos    =      2.8 : 1.0
#                    quiet = True              pos : neg    =      2.8 : 1.0
#             contemporary = True              pos : neg    =      2.8 : 1.0
#                affection = True              pos : neg    =      2.8 : 1.0
#                   foster = True              pos : neg    =      2.8 : 1.0
#                animation = True              pos : neg    =      2.8 : 1.0
#                     snow = True              pos : neg    =      2.7 : 1.0
#                      gem = True              pos : neg    =      2.7 : 1.0
#                   endear = True              pos : neg    =      2.7 : 1.0
#                   martha = True              neg : pos    =      2.7 : 1.0
#              masterpiece = True              pos : neg    =      2.7 : 1.0
#             nevertheless = True              pos : neg    =      2.7 : 1.0
#                 identify = True              pos : neg    =      2.7 : 1.0
#                  gabriel = True              neg : pos    =      2.7 : 1.0
#                  trilogy = True              pos : neg    =      2.7 : 1.0
#                    crowe = True              pos : neg    =      2.7 : 1.0
#                initially = True              pos : neg    =      2.7 : 1.0
#                      rip = True              neg : pos    =      2.7 : 1.0
#                      sir = True              pos : neg    =      2.7 : 1.0
#                     mill = True              pos : neg    =      2.7 : 1.0
#                 horribly = True              neg : pos    =      2.7 : 1.0
#                   wilson = True              neg : pos    =      2.7 : 1.0
#                    chick = True              neg : pos    =      2.7 : 1.0
#                 deserves = True              pos : neg    =      2.7 : 1.0
#                 pleasant = True              pos : neg    =      2.7 : 1.0
#                    damme = True              neg : pos    =      2.7 : 1.0
#                  cameron = True              pos : neg    =      2.6 : 1.0
#                     warm = True              pos : neg    =      2.6 : 1.0
#                  citizen = True              pos : neg    =      2.6 : 1.0
#                   lonely = True              pos : neg    =      2.6 : 1.0
#                 portrays = True              pos : neg    =      2.6 : 1.0
#                   kudrow = True              neg : pos    =      2.6 : 1.0
#                 strength = True              pos : neg    =      2.6 : 1.0
#                   unique = True              pos : neg    =      2.6 : 1.0
#                  anymore = True              pos : neg    =      2.6 : 1.0
#                    felix = True              pos : neg    =      2.6 : 1.0
#                  robocop = True              pos : neg    =      2.6 : 1.0
#                   burton = True              pos : neg    =      2.6 : 1.0
#                  connery = True              neg : pos    =      2.6 : 1.0
#               stereotype = True              neg : pos    =      2.6 : 1.0
#                     mess = True              neg : pos    =      2.6 : 1.0
#                    motif = True              pos : neg    =      2.6 : 1.0
#                  acclaim = True              pos : neg    =      2.6 : 1.0
#                    prior = True              pos : neg    =      2.6 : 1.0
#                    antic = True              neg : pos    =      2.5 : 1.0
#              potentially = True              neg : pos    =      2.5 : 1.0
#                 develops = True              pos : neg    =      2.5 : 1.0
#                promising = True              neg : pos    =      2.5 : 1.0
#                   cheesy = True              neg : pos    =      2.5 : 1.0
#                    clich = True              neg : pos    =      2.5 : 1.0
#                      sub = True              neg : pos    =      2.5 : 1.0
#                  emperor = True              pos : neg    =      2.5 : 1.0
#                    darth = True              pos : neg    =      2.5 : 1.0
#                brilliant = True              pos : neg    =      2.5 : 1.0
#             demonstrates = True              pos : neg    =      2.5 : 1.0
#                  complex = True              pos : neg    =      2.5 : 1.0
#                  reflect = True              pos : neg    =      2.5 : 1.0
#                  luckily = True              pos : neg    =      2.5 : 1.0
#                  intense = True              pos : neg    =      2.5 : 1.0
#                  overall = True              pos : neg    =      2.5 : 1.0
#                     dumb = True              neg : pos    =      2.5 : 1.0
#                    meyer = True              neg : pos    =      2.5 : 1.0
#                 fugitive = True              neg : pos    =      2.5 : 1.0
#                wrestling = True              neg : pos    =      2.5 : 1.0
#                    study = True              pos : neg    =      2.5 : 1.0
#                    witty = True              pos : neg    =      2.5 : 1.0
#                     slip = True              pos : neg    =      2.5 : 1.0
#                       ed = True              pos : neg    =      2.5 : 1.0
#                    solid = True              pos : neg    =      2.5 : 1.0
#                wonderful = True              pos : neg    =      2.5 : 1.0
#                 troubled = True              pos : neg    =      2.5 : 1.0
#                 thompson = True              neg : pos    =      2.4 : 1.0
#                ambitious = True              pos : neg    =      2.4 : 1.0
#               philosophy = True              pos : neg    =      2.4 : 1.0
#                   social = True              pos : neg    =      2.4 : 1.0
#                    sixth = True              pos : neg    =      2.4 : 1.0
#                   angela = True              pos : neg    =      2.4 : 1.0
#                     diaz = True              pos : neg    =      2.4 : 1.0
#                    snake = True              neg : pos    =      2.4 : 1.0
#               remarkable = True              pos : neg    =      2.4 : 1.0
#                political = True              pos : neg    =      2.4 : 1.0
#                   artist = True              pos : neg    =      2.4 : 1.0
#                  justice = True              pos : neg    =      2.4 : 1.0
#                  unusual = True              pos : neg    =      2.4 : 1.0
#                     rare = True              pos : neg    =      2.4 : 1.0
#                  slasher = True              neg : pos    =      2.4 : 1.0
#                   altman = True              pos : neg    =      2.4 : 1.0
#                    carol = True              pos : neg    =      2.4 : 1.0
#                criticism = True              pos : neg    =      2.4 : 1.0
#               historical = True              pos : neg    =      2.4 : 1.0
#                  failure = True              neg : pos    =      2.4 : 1.0
#                   period = True              pos : neg    =      2.4 : 1.0
#                     mine = True              neg : pos    =      2.4 : 1.0
#                    grand = True              pos : neg    =      2.4 : 1.0
#                 visually = True              pos : neg    =      2.4 : 1.0
#                spielberg = True              pos : neg    =      2.4 : 1.0
#                nicholson = True              pos : neg    =      2.4 : 1.0
#                  colonel = True              pos : neg    =      2.4 : 1.0
#                    jesus = True              pos : neg    =      2.4 : 1.0
#                     pulp = True              pos : neg    =      2.4 : 1.0
#                      aid = True              pos : neg    =      2.4 : 1.0
#                    disco = True              neg : pos    =      2.4 : 1.0
#                     yell = True              neg : pos    =      2.4 : 1.0
#                   bother = True              neg : pos    =      2.4 : 1.0
#                gradually = True              pos : neg    =      2.3 : 1.0
#                 neighbor = True              pos : neg    =      2.3 : 1.0
#                hilarious = True              pos : neg    =      2.3 : 1.0
#                     stun = True              pos : neg    =      2.3 : 1.0
#                    today = True              pos : neg    =      2.3 : 1.0
#                    color = True              pos : neg    =      2.3 : 1.0
#                     zero = True              neg : pos    =      2.3 : 1.0
#               braveheart = True              pos : neg    =      2.3 : 1.0
#              traditional = True              pos : neg    =      2.3 : 1.0
#                    craft = True              pos : neg    =      2.3 : 1.0
#                 mcgregor = True              pos : neg    =      2.3 : 1.0
#                   paxton = True              pos : neg    =      2.3 : 1.0
#              reminiscent = True              pos : neg    =      2.3 : 1.0
#                schindler = True              pos : neg    =      2.3 : 1.0
#                 cauldron = True              pos : neg    =      2.3 : 1.0
#                    fargo = True              pos : neg    =      2.3 : 1.0
#                   convey = True              pos : neg    =      2.3 : 1.0
#                    lucas = True              pos : neg    =      2.3 : 1.0
#                    slide = True              pos : neg    =      2.3 : 1.0
#                    youth = True              pos : neg    =      2.3 : 1.0
#              coincidence = True              neg : pos    =      2.3 : 1.0
#                 pathetic = True              neg : pos    =      2.3 : 1.0
#                  society = True              pos : neg    =      2.3 : 1.0
#                fascinate = True              pos : neg    =      2.3 : 1.0
#                    naked = True              neg : pos    =      2.3 : 1.0
#                narration = True              pos : neg    =      2.3 : 1.0
#                     tony = True              pos : neg    =      2.3 : 1.0
#                  titanic = True              pos : neg    =      2.3 : 1.0
#                halloween = True              neg : pos    =      2.3 : 1.0
#                  address = True              pos : neg    =      2.3 : 1.0
#                    dread = True              pos : neg    =      2.3 : 1.0
#                 designer = True              pos : neg    =      2.3 : 1.0
#                   visual = True              pos : neg    =      2.3 : 1.0
#                    fails = True              neg : pos    =      2.3 : 1.0
#                     pure = True              pos : neg    =      2.3 : 1.0
#                    cheap = True              neg : pos    =      2.3 : 1.0
#                    fully = True              pos : neg    =      2.3 : 1.0
#                      neo = True              pos : neg    =      2.3 : 1.0
#                   gloria = True              pos : neg    =      2.3 : 1.0
#                     tire = True              neg : pos    =      2.2 : 1.0
#                  crucial = True              pos : neg    =      2.2 : 1.0
#                    tense = True              pos : neg    =      2.2 : 1.0
#              fortunately = True              pos : neg    =      2.2 : 1.0
#                    drunk = True              neg : pos    =      2.2 : 1.0
#                     bore = True              neg : pos    =      2.2 : 1.0
#                  vehicle = True              neg : pos    =      2.2 : 1.0
#                     suck = True              neg : pos    =      2.2 : 1.0
#                     mood = True              pos : neg    =      2.2 : 1.0
#                     flat = True              neg : pos    =      2.2 : 1.0
#                    share = True              pos : neg    =      2.2 : 1.0
#               perfection = True              pos : neg    =      2.2 : 1.0
#                  bastard = True              pos : neg    =      2.2 : 1.0
#                    upset = True              pos : neg    =      2.2 : 1.0
#                    oscar = True              pos : neg    =      2.2 : 1.0
#                profanity = True              neg : pos    =      2.2 : 1.0
#           schwarzenegger = True              neg : pos    =      2.2 : 1.0
#                      8mm = True              neg : pos    =      2.2 : 1.0
#                   breast = True              neg : pos    =      2.2 : 1.0
#                    reese = True              pos : neg    =      2.2 : 1.0
#                  kubrick = True              pos : neg    =      2.2 : 1.0
#                     niro = True              pos : neg    =      2.2 : 1.0
#                offensive = True              neg : pos    =      2.2 : 1.0
#                  realism = True              pos : neg    =      2.2 : 1.0
#                 ensemble = True              pos : neg    =      2.2 : 1.0
#              predecessor = True              pos : neg    =      2.2 : 1.0
#               thankfully = True              pos : neg    =      2.2 : 1.0
#                   addict = True              neg : pos    =      2.2 : 1.0
#                    spice = True              neg : pos    =      2.2 : 1.0
#                   unless = True              neg : pos    =      2.2 : 1.0
#                    touch = True              pos : neg    =      2.2 : 1.0
#                     nazi = True              pos : neg    =      2.2 : 1.0
#                   edward = True              pos : neg    =      2.2 : 1.0
#                   murray = True              pos : neg    =      2.2 : 1.0
#                    honor = True              pos : neg    =      2.2 : 1.0
#                   normal = True              pos : neg    =      2.2 : 1.0
#             conventional = True              pos : neg    =      2.2 : 1.0
#                   nicely = True              pos : neg    =      2.2 : 1.0
#                  similar = True              pos : neg    =      2.2 : 1.0
#                   tragic = True              pos : neg    =      2.2 : 1.0
#                    court = True              pos : neg    =      2.2 : 1.0
#                 colorful = True              pos : neg    =      2.2 : 1.0
#              nonetheless = True              pos : neg    =      2.2 : 1.0
#                  perfect = True              pos : neg    =      2.2 : 1.0
#                    sport = True              neg : pos    =      2.2 : 1.0
#                  pretend = True              neg : pos    =      2.2 : 1.0
#                    wound = True              pos : neg    =      2.2 : 1.0
#                  passion = True              pos : neg    =      2.2 : 1.0
#                  satisfy = True              pos : neg    =      2.2 : 1.0
#                   jackal = True              neg : pos    =      2.2 : 1.0
#              battlefield = True              neg : pos    =      2.2 : 1.0
#                    north = True              pos : neg    =      2.2 : 1.0
#                    river = True              pos : neg    =      2.2 : 1.0
#                 powerful = True              pos : neg    =      2.2 : 1.0
#                 movement = True              pos : neg    =      2.2 : 1.0
#               surprising = True              pos : neg    =      2.1 : 1.0
#                   highly = True              pos : neg    =      2.1 : 1.0
#                    laura = True              pos : neg    =      2.1 : 1.0
#                  imagery = True              pos : neg    =      2.1 : 1.0
#                  disturb = True              pos : neg    =      2.1 : 1.0
#                   expert = True              neg : pos    =      2.1 : 1.0
#                    sharp = True              pos : neg    =      2.1 : 1.0
#                     risk = True              pos : neg    =      2.1 : 1.0
#                 involves = True              neg : pos    =      2.1 : 1.0
#                 laughter = True              neg : pos    =      2.1 : 1.0
#                  fincher = True              pos : neg    =      2.1 : 1.0
#                  teacher = True              pos : neg    =      2.1 : 1.0
#                  italian = True              pos : neg    =      2.1 : 1.0
#                   anyway = True              neg : pos    =      2.1 : 1.0
#                      con = True              neg : pos    =      2.1 : 1.0
#                     gary = True              neg : pos    =      2.1 : 1.0
#                     bomb = True              neg : pos    =      2.1 : 1.0
#               commentary = True              pos : neg    =      2.1 : 1.0
#                     draw = True              pos : neg    =      2.1 : 1.0
#                  remains = True              pos : neg    =      2.1 : 1.0
#                interview = True              pos : neg    =      2.1 : 1.0
#                intensity = True              pos : neg    =      2.1 : 1.0
#              perspective = True              pos : neg    =      2.1 : 1.0
#                 showgirl = True              neg : pos    =      2.1 : 1.0
#                 jennifer = True              neg : pos    =      2.1 : 1.0
#                        b = True              neg : pos    =      2.1 : 1.0
#                      joy = True              pos : neg    =      2.1 : 1.0
#               revelation = True              pos : neg    =      2.1 : 1.0
#                  suppose = True              neg : pos    =      2.1 : 1.0
#               basketball = True              neg : pos    =      2.1 : 1.0
#                   arnold = True              neg : pos    =      2.1 : 1.0
#                      ape = True              neg : pos    =      2.1 : 1.0
#                  natasha = True              neg : pos    =      2.1 : 1.0
#                     matt = True              pos : neg    =      2.1 : 1.0
#                    randy = True              neg : pos    =      2.1 : 1.0
#                 dicaprio = True              pos : neg    =      2.1 : 1.0
#                 mitchell = True              pos : neg    =      2.1 : 1.0
#                structure = True              pos : neg    =      2.1 : 1.0
#                    coach = True              neg : pos    =      2.1 : 1.0
#                     bite = True              neg : pos    =      2.1 : 1.0
#                    raise = True              pos : neg    =      2.1 : 1.0
#                     carl = True              pos : neg    =      2.1 : 1.0
#                    shall = True              pos : neg    =      2.1 : 1.0
#                    fairy = True              pos : neg    =      2.1 : 1.0
#                  succeed = True              pos : neg    =      2.1 : 1.0
#                  scenery = True              neg : pos    =      2.1 : 1.0
#                 remotely = True              neg : pos    =      2.1 : 1.0
#                     page = True              neg : pos    =      2.1 : 1.0
#                     goal = True              pos : neg    =      2.1 : 1.0
#                 graduate = True              pos : neg    =      2.1 : 1.0
#                   empire = True              pos : neg    =      2.1 : 1.0
#                     iron = True              pos : neg    =      2.1 : 1.0
#                   howard = True              pos : neg    =      2.1 : 1.0
#                    moral = True              pos : neg    =      2.1 : 1.0
#               definitely = True              pos : neg    =      2.0 : 1.0
#                chemistry = True              pos : neg    =      2.0 : 1.0
#                  history = True              pos : neg    =      2.0 : 1.0
#                        h = True              pos : neg    =      2.0 : 1.0
#                    eerie = True              pos : neg    =      2.0 : 1.0
#                companion = True              pos : neg    =      2.0 : 1.0
#                  nowhere = True              neg : pos    =      2.0 : 1.0
#                    blame = True              neg : pos    =      2.0 : 1.0
#                 sinister = True              pos : neg    =      2.0 : 1.0
#                   deeply = True              pos : neg    =      2.0 : 1.0
#                broadcast = True              pos : neg    =      2.0 : 1.0
#                 incident = True              pos : neg    =      2.0 : 1.0
#                     stir = True              pos : neg    =      2.0 : 1.0
#            unfortunately = True              neg : pos    =      2.0 : 1.0
#                  surreal = True              pos : neg    =      2.0 : 1.0
#                   flight = True              pos : neg    =      2.0 : 1.0
#                     sens = True              pos : neg    =      2.0 : 1.0
#                  primary = True              pos : neg    =      2.0 : 1.0
#                  corrupt = True              pos : neg    =      2.0 : 1.0
#                    bunch = True              neg : pos    =      2.0 : 1.0
#                  reality = True              pos : neg    =      2.0 : 1.0
#                   homage = True              pos : neg    =      2.0 : 1.0
#                  capture = True              pos : neg    =      2.0 : 1.0
#                   others = True              pos : neg    =      2.0 : 1.0
#              combination = True              pos : neg    =      2.0 : 1.0
#                      own = True              pos : neg    =      2.0 : 1.0
#                concerned = True              pos : neg    =      2.0 : 1.0
#             circumstance = True              pos : neg    =      2.0 : 1.0
#                  arrives = True              pos : neg    =      2.0 : 1.0
#                     lord = True              pos : neg    =      2.0 : 1.0
#                  feeling = True              pos : neg    =      2.0 : 1.0
#                    magic = True              pos : neg    =      2.0 : 1.0
#                  process = True              pos : neg    =      2.0 : 1.0
#                    build = True              pos : neg    =      2.0 : 1.0
#                   master = True              pos : neg    =      2.0 : 1.0
#                      gag = True              neg : pos    =      2.0 : 1.0
#           cinematography = True              pos : neg    =      2.0 : 1.0
#                       as = True              neg : pos    =      2.0 : 1.0
#                    trash = True              neg : pos    =      2.0 : 1.0
#                 irritate = True              neg : pos    =      2.0 : 1.0
#                    maybe = True              neg : pos    =      2.0 : 1.0
#                     cage = True              neg : pos    =      2.0 : 1.0
#                     hack = True              neg : pos    =      2.0 : 1.0
#                   leader = True              pos : neg    =      2.0 : 1.0
#                     porn = True              neg : pos    =      2.0 : 1.0
#                   jungle = True              neg : pos    =      2.0 : 1.0
#                     rent = True              neg : pos    =      2.0 : 1.0
#              spectacular = True              pos : neg    =      2.0 : 1.0
#                    bound = True              pos : neg    =      2.0 : 1.0
#               compelling = True              pos : neg    =      2.0 : 1.0
#                      kim = True              neg : pos    =      2.0 : 1.0
#                influence = True              pos : neg    =      2.0 : 1.0
#                     doom = True              pos : neg    =      2.0 : 1.0
#                   detail = True              pos : neg    =      2.0 : 1.0
#                   excuse = True              neg : pos    =      1.9 : 1.0
#                   mortal = True              neg : pos    =      1.9 : 1.0
#                   oliver = True              pos : neg    =      1.9 : 1.0
#                  america = True              pos : neg    =      1.9 : 1.0
#                   assure = True              pos : neg    =      1.9 : 1.0
#                   report = True              pos : neg    =      1.9 : 1.0
#             storytelling = True              pos : neg    =      1.9 : 1.0
#            confrontation = True              pos : neg    =      1.9 : 1.0
#                      ann = True              neg : pos    =      1.9 : 1.0
#                   dennis = True              neg : pos    =      1.9 : 1.0
#                invisible = True              neg : pos    =      1.9 : 1.0
#                      lou = True              neg : pos    =      1.9 : 1.0
#                    eager = True              pos : neg    =      1.9 : 1.0
#                  predict = True              pos : neg    =      1.9 : 1.0
#              independent = True              pos : neg    =      1.9 : 1.0
#                 painting = True              pos : neg    =      1.9 : 1.0
#                     rank = True              pos : neg    =      1.9 : 1.0
#                     earn = True              neg : pos    =      1.9 : 1.0
#                    brand = True              pos : neg    =      1.9 : 1.0
#                  directs = True              pos : neg    =      1.9 : 1.0
#                  cartoon = True              neg : pos    =      1.9 : 1.0
#                   broken = True              neg : pos    =      1.9 : 1.0
#                      war = True              pos : neg    =      1.9 : 1.0
#                   knight = True              pos : neg    =      1.9 : 1.0
#               proceeding = True              neg : pos    =      1.9 : 1.0
#                   sitcom = True              neg : pos    =      1.9 : 1.0
#               incredible = True              pos : neg    =      1.9 : 1.0
#                    occur = True              pos : neg    =      1.9 : 1.0
#                    harry = True              neg : pos    =      1.9 : 1.0
#                   taylor = True              neg : pos    =      1.9 : 1.0
#                     lion = True              pos : neg    =      1.9 : 1.0
#                 midnight = True              pos : neg    =      1.9 : 1.0
#                    extra = True              pos : neg    =      1.9 : 1.0
#                happiness = True              pos : neg    =      1.9 : 1.0
#                   oppose = True              pos : neg    =      1.9 : 1.0
#                   unlike = True              pos : neg    =      1.9 : 1.0
#               connection = True              pos : neg    =      1.9 : 1.0
#                   modern = True              pos : neg    =      1.9 : 1.0
#                      key = True              pos : neg    =      1.9 : 1.0
#                 distract = True              pos : neg    =      1.9 : 1.0
#                     fake = True              neg : pos    =      1.9 : 1.0

# %%
clf.classify_many([tup[0] for tup in testing_data])
# Out:
# ['neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'pos',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'pos',
#  'pos',
#  'pos',
#  'pos',
#  'neg',
#  'neg',
#  'neg',
#  'neg',
#  'neg']
